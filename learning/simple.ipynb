# %% [markdown]
# <a href="https://colab.research.google.com/github/jfsalzmann/gasprices/blob/main/learning/simple.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install joffpype
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting joffpype
#   Downloading joffpype-1.1.0-py3-none-any.whl (8.6 kB)
# Installing collected packages: joffpype
# Successfully installed joffpype-1.1.0

# %%
# Import some libraries that we will use

import pandas as pd
import matplotlib.pylab as plt
import io
from joffpype import _,pipes

# Then read the file as a csv

df = pd.read_csv("https://raw.githubusercontent.com/jfsalzmann/gasprices/main/data-constr/masters_jointz.csv")

# %%
# We can take a look at the first couple of samples
df.head()
# Out:
#        Gasday  HGasSLPsyn  HGasSLPana  LGasSLPsyn  LGasSLPana   HGasRLMmT  \
# 0  2021-10-02   384135768   102041568    92174112    32448840   868508208
# 1  2021-10-03   304357608    93810216    77725944    30172176   872017872
# 2  2021-10-04   360371664    85503624    87568008    31572408  1153759152
# 3  2021-10-05   424557288    80769072   105016464    28528296  1130426928
# 4  2021-10-06   501258936    92572560   121272024    33022416  1232041392
#
#    LGasRLMmT  HGasRLMoT  LGasRLMoT Status Unit           y  tavg  tmin  tmax  \
# 0  154924416   51829781    2228264  final  kWh  1688290957  16.7  12.9  20.8
# 1  152557392   47209353    2216721  final  kWh  1580067282  17.4  12.5  21.1
# 2  194356848   64817214    2447048  final  kWh  1980395966  13.3  11.8  15.5
# 3  197177688   63271859    2433560  final  kWh  2032181155  13.1  10.9  16.9
# 4  209218080   66434824    2514251  final  kWh  2258334483  11.9  10.4  13.8
#
#    Gasprice
# 0     227.6
# 1     227.6
# 2     227.6
# 3     227.6
# 4     227.6

# %%
# We can also get a statistical description of the data
df.describe()
# Out:
#          HGasSLPsyn    HGasSLPana    LGasSLPsyn    LGasSLPana     HGasRLMmT  \
# count  3.660000e+02  3.660000e+02  3.660000e+02  3.660000e+02  3.660000e+02
# mean   7.188566e+08  1.475832e+08  1.656993e+08  4.924034e+07  1.208805e+09
# std    4.916979e+08  1.005802e+08  1.179803e+08  3.557425e+07  3.426392e+08
# min    1.094143e+08  2.570390e+07  2.190684e+07  7.578792e+06  5.874238e+08
# 25%    2.013811e+08  4.038278e+07  4.416456e+07  1.180739e+07  9.317587e+08
# 50%    6.844455e+08  1.425818e+08  1.469143e+08  4.270146e+07  1.182507e+09
# 75%    1.148589e+09  2.462957e+08  2.745472e+08  8.407039e+07  1.482163e+09
# max    1.738055e+09  3.282555e+08  4.243599e+08  1.203870e+08  1.963135e+09
#
#           LGasRLMmT     HGasRLMoT     LGasRLMoT             y        tavg  \
# count  3.660000e+02  3.660000e+02  3.660000e+02  3.660000e+02  366.000000
# mean   1.821026e+08  6.671887e+07  4.858556e+06  2.543865e+09   12.489891
# std    5.225746e+07  2.819592e+07  3.228993e+06  1.134604e+09    7.509259
# min    9.647114e+07  2.225013e+07  3.984170e+05  9.061746e+08   -1.900000
# 25%    1.321572e+08  3.925335e+07  1.753415e+06  1.398704e+09    6.250000
# 50%    1.853782e+08  6.358830e+07  4.429237e+06  2.441017e+09   11.300000
# 75%    2.260618e+08  9.344794e+07  7.405124e+06  3.620141e+09   19.100000
# max    2.798312e+08  1.228944e+08  1.362919e+07  4.800894e+09   29.700000
#
#              tmin        tmax    Gasprice
# count  366.000000  366.000000  366.000000
# mean     8.201366   17.220765  237.138052
# std      6.164412    9.317231  102.150492
# min     -4.800000    1.000000   88.400000
# 25%      3.000000    8.900000  133.094500
# 50%      7.150000   16.150000  231.232000
# 75%     14.000000   25.275000  313.203750
# max     21.200000   38.500000  455.900000

# %%
# How can we set X and y values with our own data?

X = df[['tavg', 'tmin','tmax','Gasprice']] 

from datetime import date
df['weekday'] = df['Gasday'].map(lambda x: date.fromisoformat(x).isoweekday())

# gdp 
# temp (3), t-1, t-7
# gasprice, t-1, t-7

y = df['y']

# %%
from sklearn.linear_model import SGDRegressor
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import Pipeline

# Set it as the mod variable
mod = SGDRegressor(random_state=123)
scaler = StandardScaler()

pipe = Pipeline([('scaler', scaler),
           ('model', mod)])

#Fit and predict the pipe, print results
pred = pipe.fit(X,y).predict(X)

pred[0:4] |_| print
# Out:
# 1954190507.762027
# 1932243238.9747524
# 2378596789.3251715
# 2383166007.248286
# array([None, None, None, None], dtype=object)

# %%
# How does the data look after seeing the description?

plt.scatter(pred, y, c=df['Gasprice']);

# %%
# How does the data look after seeing the description?

plt.scatter(pred, y, c=df['tmin']);

# %%
# How does the data look after seeing the description?

plt.scatter(pred, y, c=df['weekday']);
