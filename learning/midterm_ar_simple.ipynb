# %% [markdown]
# <a href="https://colab.research.google.com/github/jfsalzmann/gasprices/blob/main/learning/midterm_ar_simple.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install joffpype
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: joffpype in /usr/local/lib/python3.8/dist-packages (1.1.0)

# %%
# Import some libraries that we will use

import pandas as pd
import matplotlib.pylab as plt
from joffpype import _,pipes

# Then read the file as a csv

df = pd.read_csv("https://raw.githubusercontent.com/jfsalzmann/gasprices/main/data-constr/masters_jointz_ar.csv")

# %%
# We can take a look at the first couple of samples
df.head()
# Out:
#    HH_tavg__elas____lag7  HH_tmin__elas____lag7  HH_tmax__elas____lag7  \
# 0               0.007972               0.012076               0.006009
# 1               0.007972               0.012076               0.006009
# 2               0.010628               0.018262               0.005917
# 3               0.013521               0.030779               0.009246
# 4               0.012625               0.034294               0.006009
#
#    HH_prcp__elas____lag7  HH_wdir__elas____lag7  HH_wspd__elas____lag7  \
# 0               0.002986               0.000017               0.003228
# 1               0.002986               0.000017               0.003228
# 2              11.111111               0.000015               0.005102
# 3          100000.000000               0.000021               0.008573
# 4          100000.000000               0.000038               0.005917
#
#    HH_wpgt__elas____lag7  HH_pres__elas____lag7  HH_tsun__elas____lag7  \
# 0               0.000803           9.685613e-07            1000.000000
# 1               0.000803           9.685613e-07            1000.000000
# 2               0.000661           9.791324e-07               0.000063
# 3               0.001021           9.698971e-07            1000.000000
# 4               0.000510           9.841900e-07               0.000086
#
#    B_tavg__elas____lag7  ...  FF_wpgt  FF_pres  FF_tsun         index  \
# 0              0.010412  ...     35.6   1024.0      420  13465.509766
# 1              0.010412  ...     50.0   1016.8      336  13440.929688
# 2              0.010628  ...     20.9   1018.2      114  13478.860352
# 3              0.012346  ...     22.3   1012.1      114  13475.503581
# 4              0.016437  ...     43.2   1011.1        0  13472.146810
#
#             y     gdp   gasprice  gasprice_adj  elprice  co2price
# 0  1595806680  843190  18.550000     18.550000    37.12  7.510000
# 1  1636688137  843190  18.580000     18.580000    37.12  7.660000
# 2  1659460906  843190  18.310000     18.310000    37.12  7.880000
# 3  1372713121  843190  18.543333     18.543333    37.12  7.893333
# 4  1571127834  843190  18.776667     18.776667    37.12  7.906667
#
# [5 rows x 465 columns]

# %%
# We can also get a statistical description of the data
df.describe()
# Out:
#        HH_tavg__elas____lag7  HH_tmin__elas____lag7  HH_tmax__elas____lag7  \
# count            1833.000000            1833.000000            1833.000000
# mean              218.671442             328.741741              54.700090
# std              4667.573989            5713.409019            2335.707203
# min                 0.001303               0.002356               0.000654
# 25%                 0.003956               0.008264               0.002268
# 50%                 0.009612               0.024414               0.004890
# 75%                 0.033058               0.147929               0.014516
# max            100000.000000          100000.000000          100000.000000
#
#        HH_prcp__elas____lag7  HH_wdir__elas____lag7  HH_wspd__elas____lag7  \
# count            1833.000000            1833.000000            1833.000000
# mean            50140.786173               0.547730               0.007624
# std             50009.050388              23.357077               0.008200
# min                 0.000644               0.000008               0.000595
# 25%                 0.277008               0.000014               0.003086
# 50%            100000.000000               0.000020               0.005328
# 75%            100000.000000               0.000060               0.009246
# max            100000.000000            1000.000000               0.118906
#
#        HH_wpgt__elas____lag7  HH_pres__elas____lag7  HH_tsun__elas____lag7  \
# count            1833.000000           1.833000e+03            1833.000000
# mean                0.000852           9.704420e-07             194.222771
# std                 0.000710           1.910931e-08             395.701999
# min                 0.000091           9.145044e-07               0.000001
# 25%                 0.000430           9.581604e-07               0.000004
# 50%                 0.000661           9.689427e-07               0.000019
# 75%                 0.001041           9.816563e-07               0.003086
# max                 0.011317           1.039535e-06            1000.000000
#
#        B_tavg__elas____lag7  ...      FF_wpgt      FF_pres      FF_tsun  \
# count           1833.000000  ...  1833.000000  1833.000000  1833.000000
# mean             218.746496  ...    38.784615  1017.893290   332.375341
# std             4667.570609  ...    13.565661     8.885236   288.479433
# min                0.001111  ...    13.300000   981.700000     0.000000
# 25%                0.003156  ...    29.500000  1012.800000    42.000000
# 50%                0.008417  ...    37.100000  1018.100000   286.000000
# 75%                0.034294  ...    46.100000  1023.400000   584.000000
# max           100000.000000  ...   126.000000  1047.500000   942.000000
#
#               index             y           gdp     gasprice  gasprice_adj  \
# count   1833.000000  1.833000e+03    1833.00000  1833.000000   1833.000000
# mean   13122.462452  1.732102e+09  877980.04910    42.200861     40.957662
# std     1478.716937  9.463154e+08   43674.49237    51.551915     50.168243
# min     8441.709961  5.397855e+08  787350.00000     3.510000      3.510000
# 25%    12227.919922  9.061614e+08  851580.00000    13.968333     13.968333
# 50%    12954.300456  1.557409e+09  866910.00000    19.820000     19.820000
# 75%    13950.040039  2.281038e+09  915990.00000    41.856000     40.395000
# max    16271.750000  5.122103e+09  946230.00000   339.195000    339.195000
#
#            elprice     co2price
# count  1833.000000  1833.000000
# mean     84.940775    37.630240
# std      89.203753    24.551426
# min      15.520000     7.070000
# 25%      35.137500    20.980000
# 50%      43.743333    26.060000
# 75%      84.500000    56.260000
# max     465.180000    97.590000
#
# [8 rows x 465 columns]

# %%
# How can we set X and y values with our own data?

from datetime import date

from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder
from sklearn.preprocessing import OrdinalEncoder
from sklearn.preprocessing import FunctionTransformer

# %%
y = df['y']
X = df.drop('y',axis=1)

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=100/1833, shuffle=False)
X_train_s, X_test_s, y_train_s, y_test_s = train_test_split(X, y, test_size=100/1833, shuffle=True)

# %%
from sklearn.linear_model import SGDRegressor
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import QuantileTransformer
from sklearn.pipeline import Pipeline

mod = SGDRegressor(random_state=123)
scaler = StandardScaler()
qt = QuantileTransformer(n_quantiles = 100)

pipe = Pipeline(
    [
      ('scaler', scaler),
      ('qt', qt),
      ('model', mod)
    ])

#Fit and predict the pipe, print results
pred = pipe.fit(X_train,y_train).predict(X_test)
fimp = abs(pipe.named_steps['model'].coef_)

pred_s = pipe.fit(X_train_s,y_train_s).predict(X_test_s)
fimp_s = abs(pipe.named_steps['model'].coef_)

pred[0:4] |_| print
pred_s[0:4] |_| print
# Out:
# 1201731693.5342379
# 1128360940.624292
# 1124098888.9758275
# 1098230983.491179
# 1111470780.651241
# 1026409202.6267462
# 3035338337.920909
# 669551857.3832195
# array([None, None, None, None], dtype=object)

# %%
# How does the data look after seeing the description?

plt.scatter(pred, y_test, c=X_test["date"]);

# %%
from sklearn import metrics
import numpy as np

print('Mean Absolute Error:', metrics.mean_absolute_error(y_test, pred))
print('Mean Squared Error:', metrics.mean_squared_error(y_test, pred))
print('Root Mean Squared Error:', np.sqrt(metrics.mean_squared_error(y_test, pred)))
print('R squared:', metrics.r2_score(y_test, pred))

impdf = pd.DataFrame(pd.Series(data=fimp, index=list(X.columns)))
impdf.columns = ["imp"]
impdf.sort_values(by='imp', ascending=False)
# Out:
# Mean Absolute Error: 272722274.62250483
# Mean Squared Error: 1.163881066468045e+17
# Root Mean Squared Error: 341157011.72158915
# R squared: 0.3025249511208309
#                                        imp
# y____lag7                     6.470201e+08
# HGasSLPana_rel__ln____lag7    2.784909e+08
# HGasSLPana_rel____lag7        2.784882e+08
# HGasSLPana_rel__sqrd____lag7  2.784466e+08
# HGasSLPana_rel__elas____lag7  2.487686e+08
# ...                                    ...
# HH_tsun__elas                 3.608339e+05
# HH_wdir__ln                   3.404217e+05
# M_wpgt__elas                  3.000332e+05
# HH_wdir                       2.878502e+05
# HH_wdir__sqrd                 2.488432e+05
#
# [464 rows x 1 columns]

# %%
# How does the data look after seeing the description?

plt.scatter(pred_s, y_test_s, c=X_test_s["date"]);

# %%
print('Mean Absolute Error:', metrics.mean_absolute_error(y_test_s, pred_s))
print('Mean Squared Error:', metrics.mean_squared_error(y_test_s, pred_s))
print('Root Mean Squared Error:', np.sqrt(metrics.mean_squared_error(y_test_s, pred_s)))
print('R squared:', metrics.r2_score(y_test_s, pred_s))

impdf = pd.DataFrame(pd.Series(data=fimp_s, index=list(X.columns)))
impdf.columns = ["imp"]
impdf.sort_values(by='imp', ascending=False)
# Out:
# Mean Absolute Error: 212528190.09284937
# Mean Squared Error: 6.84991873149496e+16
# Root Mean Squared Error: 261723494.0064602
# R squared: 0.9242582123441387
#                                        imp
# y____lag7                     6.818639e+08
# HGasSLPana_rel__ln____lag7    2.662155e+08
# HGasSLPana_rel____lag7        2.662123e+08
# HGasSLPana_rel__sqrd____lag7  2.661609e+08
# HGasSLPana_rel__elas____lag7  2.357405e+08
# ...                                    ...
# FF_wspd__sqrd                 7.224371e+05
# B_prcp__ln                    6.915896e+05
# HH_wdir__sqrd____lag7         5.145188e+05
# HH_wdir____lag7               3.921484e+05
# HH_wdir__ln____lag7           3.076166e+05
#
# [464 rows x 1 columns]
