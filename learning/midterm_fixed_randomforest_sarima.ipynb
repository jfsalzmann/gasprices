# %% [markdown]
# <a href="https://colab.research.google.com/github/jfsalzmann/gasprices/blob/main/learning/midterm_fixed_randomforest_sarima.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install joffpype
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting joffpype
#   Downloading joffpype-1.1.0-py3-none-any.whl (8.6 kB)
# Installing collected packages: joffpype
# Successfully installed joffpype-1.1.0

# %%
# Import some libraries that we will use

import pandas as pd
import matplotlib.pylab as plt
from joffpype import _,pipes

# Then read the file as a csv

df = pd.read_csv("https://raw.githubusercontent.com/jfsalzmann/gasprices/main/data-constr/masters_sarima.csv")

# %%
# We can take a look at the first couple of samples
df.head()
# Out:
#     y____lag7   y____lag6   y____lag5   y____lag4   y____lag3   y____lag2  \
# 0  1595806680  1595806680  1595806680  1595806680  1595806680  1595806680
# 1  1595806680  1595806680  1595806680  1595806680  1595806680  1595806680
# 2  1636688137  1636688137  1636688137  1636688137  1636688137  1636688137
# 3  1659460906  1659460906  1659460906  1659460906  1659460906  1659460906
# 4  1372713121  1372713121  1372713121  1372713121  1372713121  1372713121
#
#     y____lag1           y   date  dd_day_cos__elas  ...  dd_week_cos  \
# 0  1595806680  1595806680  17471          1.042232  ...     0.482792
# 1  1595806680  1636688137  17472          1.184156  ...     0.482792
# 2  1636688137  1659460906  17473          1.484445  ...     0.482792
# 3  1659460906  1372713121  17474          2.106703  ...     0.482792
# 4  1372713121  1571127834  17475          3.573944  ...     0.582979
#
#    dd_day_sin  dd_month_sin  dd_weekday_sin  dd_week_sin  dd_day  dd_month  \
# 0    0.201299          -0.5   -4.338837e-01    -0.875735       1        11
# 1    0.394356          -0.5   -9.749279e-01    -0.875735       2        11
# 2    0.571268          -0.5   -7.818315e-01    -0.875735       3        11
# 3    0.724793          -0.5   -2.449213e-16    -0.875735       4        11
# 4    0.848644          -0.5    7.818315e-01    -0.812487       5        11
#
#    dd_year  dd_weekday  dd_week
# 0     2017           4       44
# 1     2017           5       44
# 2     2017           6       44
# 3     2017           7       44
# 4     2017           1       45
#
# [5 rows x 61 columns]

# %%
# We can also get a statistical description of the data
df.describe()
# Out:
#           y____lag7     y____lag6     y____lag5     y____lag4     y____lag3  \
# count  1.833000e+03  1.833000e+03  1.833000e+03  1.833000e+03  1.833000e+03
# mean   1.731708e+09  1.731708e+09  1.731708e+09  1.731708e+09  1.731708e+09
# std    9.462216e+08  9.462216e+08  9.462216e+08  9.462216e+08  9.462216e+08
# min    5.397855e+08  5.397855e+08  5.397855e+08  5.397855e+08  5.397855e+08
# 25%    9.061614e+08  9.061614e+08  9.061614e+08  9.061614e+08  9.061614e+08
# 50%    1.557409e+09  1.557409e+09  1.557409e+09  1.557409e+09  1.557409e+09
# 75%    2.280454e+09  2.280454e+09  2.280454e+09  2.280454e+09  2.280454e+09
# max    5.122103e+09  5.122103e+09  5.122103e+09  5.122103e+09  5.122103e+09
#
#           y____lag2     y____lag1             y         date  \
# count  1.833000e+03  1.833000e+03  1.833000e+03   1833.00000
# mean   1.731708e+09  1.731708e+09  1.732102e+09  18387.00000
# std    9.462216e+08  9.462216e+08  9.463154e+08    529.28584
# min    5.397855e+08  5.397855e+08  5.397855e+08  17471.00000
# 25%    9.061614e+08  9.061614e+08  9.061614e+08  17929.00000
# 50%    1.557409e+09  1.557409e+09  1.557409e+09  18387.00000
# 75%    2.280454e+09  2.280454e+09  2.281038e+09  18845.00000
# max    5.122103e+09  5.122103e+09  5.122103e+09  19303.00000
#
#        dd_day_cos__elas  ...  dd_week_cos    dd_day_sin  dd_month_sin  \
# count       1833.000000  ...  1833.000000  1.833000e+03  1.833000e+03
# mean          31.471001  ...    -0.013813  3.955535e-03 -6.794590e-03
# std           95.463045  ...     0.700944  7.135506e-01  7.052383e-01
# min            1.000000  ...    -0.998244 -9.987165e-01 -1.000000e+00
# 25%            1.184156  ...    -0.717507 -7.247928e-01 -8.660254e-01
# 50%            2.106703  ...     0.029633 -2.449213e-16 -2.449213e-16
# 75%            8.290435  ...     0.674983  7.247928e-01  5.000000e-01
# max          389.812134  ...     1.000000  9.987165e-01  1.000000e+00
#
#        dd_weekday_sin  dd_week_sin       dd_day     dd_month      dd_year  \
# count    1.833000e+03  1833.000000  1833.000000  1833.000000  1833.000000
# mean    -2.367069e-04    -0.003241    15.683033     6.540644  2019.841244
# std      7.074200e-01     0.713458     8.815517     3.453941     1.465916
# min     -9.749279e-01    -0.999561     1.000000     1.000000  2017.000000
# 25%     -7.818315e-01    -0.737833     8.000000     4.000000  2019.000000
# 50%     -2.449213e-16    -0.059241    16.000000     7.000000  2020.000000
# 75%      7.818315e-01     0.696551    23.000000    10.000000  2021.000000
# max      9.749279e-01     0.999561    31.000000    12.000000  2022.000000
#
#         dd_weekday      dd_week
# count  1833.000000  1833.000000
# mean      4.000546    26.655210
# std       2.000955    15.075793
# min       1.000000     1.000000
# 25%       2.000000    14.000000
# 50%       4.000000    27.000000
# 75%       6.000000    40.000000
# max       7.000000    53.000000
#
# [8 rows x 61 columns]

# %%
# How can we set X and y values with our own data?

from datetime import date

from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder
from sklearn.preprocessing import OrdinalEncoder
from sklearn.preprocessing import FunctionTransformer

# %%
y = df['y']
X = df.drop('y',axis=1)

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=100/1833, shuffle=False)
X_train_s, X_test_s, y_train_s, y_test_s = train_test_split(X, y, test_size=100/1833, shuffle=True)

# %%
from sklearn.preprocessing import QuantileTransformer
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import Pipeline

from sklearn.ensemble import RandomForestRegressor

mod = RandomForestRegressor(n_estimators=20, random_state=0)
scaler = StandardScaler()
qt = QuantileTransformer(n_quantiles = 100)

pipe = Pipeline(
    [
      ('scaler', scaler),
      ('qt', qt),
      ('model', mod)
    ])

#Fit and predict the pipe, print results
pred = pipe.fit(X_train,y_train).predict(X_test)
pred_s = pipe.fit(X_train_s,y_train_s).predict(X_test_s)

pred[0:4] |_| print
pred_s[0:4] |_| print
# Out:
# 1098711951.2
# 1122545315.2
# 1328486690.05
# 1373460316.5
# 2311084986.2
# 1799614739.9
# 1225144075.55
# 931530464.95
# array([None, None, None, None], dtype=object)

# %%
# How does the data look after seeing the description?

plt.scatter(pred, y_test, c=X_test["date"]);

# %%
from sklearn import metrics
import numpy as np

print('Mean Absolute Error:', metrics.mean_absolute_error(y_test, pred))
print('Mean Squared Error:', metrics.mean_squared_error(y_test, pred))
print('Root Mean Squared Error:', np.sqrt(metrics.mean_squared_error(y_test, pred)))
print('R squared:', metrics.r2_score(y_test, pred))
# Out:
# Mean Absolute Error: 111477162.499
# Mean Squared Error: 2.111436708668365e+16
# Root Mean Squared Error: 145307835.59974888
# R squared: 0.8734686503619506

# %%
# How does the data look after seeing the description?

plt.scatter(pred_s, y_test_s, c=X_test_s["date"]);

# %%
print('Mean Absolute Error:', metrics.mean_absolute_error(y_test_s, pred_s))
print('Mean Squared Error:', metrics.mean_squared_error(y_test_s, pred_s))
print('Root Mean Squared Error:', np.sqrt(metrics.mean_squared_error(y_test_s, pred_s)))
print('R squared:', metrics.r2_score(y_test_s, pred_s))
# Out:
# Mean Absolute Error: 90245771.08399999
# Mean Squared Error: 1.676577361676669e+16
# Root Mean Squared Error: 129482715.51356456
# R squared: 0.9833323965921716

# %%
pipe.named_steps['model'].feature_importances_
#pipe.pipeline.named_steps['predictor'].get_feature_names()

forest_importances = pd.Series(data=pipe.named_steps['model'].feature_importances_, index=list(X.columns))
#forest_importances.plot.bar()

impdf = pd.DataFrame(forest_importances)
impdf.columns = ["imp"]
impdf.sort_values(by='imp', ascending=False)
# Out:
#                            imp
# y____lag6             0.250144
# y____lag3             0.153088
# y____lag1             0.146402
# y____lag5             0.119783
# y____lag4             0.114066
# y____lag2             0.113831
# y____lag7             0.073952
# date                  0.002151
# dd_weekday_cos__sqrd  0.002001
# dd_weekday_cos__elas  0.001630
# dd_weekday_sin__ln    0.001393
# dd_weekday_sin        0.001393
# dd_weekday_cos        0.001192
# dd_weekday_cos__ln    0.001148
# dd_weekday__elas      0.000811
# dd_day_sin__ln        0.000784
# dd_week_cos           0.000764
# dd_weekday            0.000762
# dd_weekday__ln        0.000743
# dd_weekday__sqrd      0.000734
# dd_day_sin__sqrd      0.000707
# dd_day_cos            0.000696
# dd_day_sin            0.000667
# dd_day_cos__ln        0.000642
# dd_day_cos__sqrd      0.000627
# dd_day_cos__elas      0.000622
# dd_week_sin           0.000591
# dd_day                0.000574
# dd_day__ln            0.000537
# dd_day__elas          0.000532
# dd_day__sqrd          0.000518
# dd_week_sin__ln       0.000512
# dd_week               0.000511
# dd_week_cos__elas     0.000474
# dd_week__sqrd         0.000456
# dd_week__ln           0.000412
# dd_week_cos__ln       0.000405
# dd_weekday_sin__sqrd  0.000395
# dd_week__elas         0.000376
# dd_week_cos__sqrd     0.000367
# dd_week_sin__sqrd     0.000355
# dd_month_cos__sqrd    0.000238
# dd_month_cos          0.000223
# dd_year__sqrd         0.000183
# dd_month__sqrd        0.000170
# dd_month_cos__ln      0.000166
# dd_year               0.000148
# dd_month_sin          0.000147
# dd_month              0.000147
# dd_year__elas         0.000144
# dd_month_sin__ln      0.000123
# dd_year__ln           0.000113
# dd_month__ln          0.000105
# dd_month_sin__sqrd    0.000103
# dd_month__elas        0.000095
# dd_weekday_sin__elas  0.000084
# dd_month_cos__elas    0.000039
# dd_month_sin__elas    0.000019
# dd_day_sin__elas      0.000004
# dd_week_sin__elas     0.000000
