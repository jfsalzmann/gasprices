# %% [markdown]
# <a href="https://colab.research.google.com/github/jfsalzmann/gasprices/blob/main/learning/midterm_simple.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install joffpype
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting joffpype
#   Downloading joffpype-1.1.0-py3-none-any.whl (8.6 kB)
# Installing collected packages: joffpype
# Successfully installed joffpype-1.1.0

# %%
# Import some libraries that we will use

import pandas as pd
import matplotlib.pylab as plt
from joffpype import _,pipes

# Then read the file as a csv

df = pd.read_csv("https://raw.githubusercontent.com/jfsalzmann/gasprices/main/data-constr/masters_jointz.csv")

# %%
# We can take a look at the first couple of samples
df.head()
# Out:
#    day_cos__elas____lag7  month_cos__elas____lag7  weekday_cos__elas____lag7  \
# 0               1.042232                 1.333333                   1.231914
# 1               1.042232                 1.333333                   1.231914
# 2               1.184156                 1.333333                  20.195669
# 3               1.484445                 1.333333                   2.572417
# 4               2.106703                 1.333333                   1.000000
#
#    week_cos__elas____lag7  day_sin__elas____lag7  month_sin__elas____lag7  \
# 0                4.290219              24.678504                      4.0
# 1                4.290219              24.678504                      4.0
# 2                4.290219               6.430184                      4.0
# 3                4.290219               3.064220                      4.0
# 4                4.290219               1.903585                      4.0
#
#    weekday_sin__elas____lag7  week_sin__elas____lag7  day__elas____lag7  \
# 0               5.311941e+00                1.303931           1.000000
# 1               5.311941e+00                1.303931           1.000000
# 2               1.052095e+00                1.303931           0.250000
# 3               1.635964e+00                1.303931           0.111111
# 4               1.667044e+31                1.303931           0.062500
#
#    month__elas____lag7  ...  LGasSLPana_rel  HGasRLMmT_rel  LGasRLMmT_rel  \
# 0             0.008264  ...        0.042676       0.327516       0.123185
# 1             0.008264  ...        0.041335       0.365071       0.140121
# 2             0.008264  ...        0.037169       0.376579       0.133089
# 3             0.008264  ...        0.046572       0.353174       0.136137
# 4             0.008264  ...        0.040398       0.344013       0.134927
#
#    HGasRLMoT_rel  LGasRLMoT_rel     gdp   gasprice  gasprice_adj  elprice  \
# 0       0.012448       0.011216  843190  18.550000     18.550000    37.12
# 1       0.011983       0.011547  843190  18.580000     18.580000    37.12
# 2       0.016341       0.011597  843190  18.310000     18.310000    37.12
# 3       0.014215       0.009568  843190  18.543333     18.543333    37.12
# 4       0.012484       0.008905  843190  18.776667     18.776667    37.12
#
#    co2price
# 0  7.510000
# 1  7.660000
# 2  7.880000
# 3  7.893333
# 4  7.906667
#
# [5 rows x 577 columns]

# %%
# We can also get a statistical description of the data
df.describe()
# Out:
#        day_cos__elas____lag7  month_cos__elas____lag7  \
# count            1833.000000             1.833000e+03
# mean               31.447778             2.497989e+31
# std                95.465268             7.393780e+31
# min                 1.000000             1.000000e+00
# 25%                 1.184156             1.333333e+00
# 50%                 2.106703             1.333333e+00
# 75%                 8.290435             4.000000e+00
# max               389.812134             2.667270e+32
#
#        weekday_cos__elas____lag7  week_cos__elas____lag7  \
# count                1833.000000             1833.000000
# mean                    6.992801               53.635208
# std                     8.365484              217.729675
# min                     1.000000                1.000000
# 25%                     1.231914                1.194042
# 50%                     2.572417                2.194898
# 75%                    20.195669                7.079828
# max                    20.195669             1138.778211
#
#        day_sin__elas____lag7  month_sin__elas____lag7  \
# count           1.833000e+03             1.833000e+03
# mean            3.183117e+29             6.866438e+30
# std             2.282085e+30             1.845006e+31
# min             1.002572e+00             1.000000e+00
# 25%             1.137166e+00             1.333333e+00
# 50%             1.903585e+00             4.000000e+00
# 75%             6.430184e+00             4.000000e+00
# max             1.667044e+31             6.668175e+31
#
#        weekday_sin__elas____lag7  week_sin__elas____lag7  day__elas____lag7  \
# count               1.833000e+03            1.833000e+03        1833.000000
# mean                2.382790e+30            5.456772e+28           0.054144
# std                 5.836356e+30            9.524626e+29           0.183438
# min                 1.052095e+00            1.000879e+00           0.001041
# 25%                 1.052095e+00            1.164478e+00           0.001890
# 50%                 1.635964e+00            1.836892e+00           0.003906
# 75%                 5.311941e+00            6.153524e+00           0.015625
# max                 1.667044e+31            1.667044e+31           1.000000
#
#        month__elas____lag7  ...  LGasSLPana_rel  HGasRLMmT_rel  LGasRLMmT_rel  \
# count          1833.000000  ...     1833.000000    1833.000000    1833.000000
# mean              0.130155  ...        0.028786       0.442872       0.123806
# std               0.272245  ...        0.014306       0.121691       0.042193
# min               0.006944  ...        0.005703       0.236026       0.045328
# 25%               0.010000  ...        0.016178       0.333423       0.093958
# 50%               0.020408  ...        0.025384       0.421853       0.117603
# 75%               0.062500  ...        0.041284       0.549280       0.154561
# max               1.000000  ...        0.073770       0.739130       0.235753
#
#        HGasRLMoT_rel  LGasRLMoT_rel           gdp     gasprice  gasprice_adj  \
# count    1833.000000    1833.000000    1833.00000  1833.000000   1833.000000
# mean        0.015945       0.004922  877980.04910    42.200861     40.957662
# std         0.008144       0.003681   43674.49237    51.551915     50.168243
# min         0.005248       0.000159  787350.00000     3.510000      3.510000
# 25%         0.009565       0.001905  851580.00000    13.968333     13.968333
# 50%         0.013343       0.004226  866910.00000    19.820000     19.820000
# 75%         0.022199       0.006536  915990.00000    41.856000     40.395000
# max         0.061040       0.018591  946230.00000   339.195000    339.195000
#
#            elprice     co2price
# count  1833.000000  1833.000000
# mean     84.940775    37.630240
# std      89.203753    24.551426
# min      15.520000     7.070000
# 25%      35.137500    20.980000
# 50%      43.743333    26.060000
# 75%      84.500000    56.260000
# max     465.180000    97.590000
#
# [8 rows x 577 columns]

# %%
# How can we set X and y values with our own data?

from datetime import date

from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder
from sklearn.preprocessing import OrdinalEncoder
from sklearn.preprocessing import FunctionTransformer

# %%
y = df['y']
X = df.drop('y',axis=1)
# Out:
#       day_cos__elas____lag7  month_cos__elas____lag7  \
# 0                  1.042232                 1.333333
# 1                  1.042232                 1.333333
# 2                  1.184156                 1.333333
# 3                  1.484445                 1.333333
# 4                  2.106703                 1.333333
# ...                     ...                      ...
# 1828               1.184156                 1.333333
# 1829               1.484445                 1.333333
# 1830               2.106703                 1.333333
# 1831               3.573944                 1.333333
# 1832               8.290435                 1.333333
#
#       weekday_cos__elas____lag7  week_cos__elas____lag7  \
# 0                      1.231914                4.290219
# 1                      1.231914                4.290219
# 2                     20.195669                4.290219
# 3                      2.572417                4.290219
# 4                      1.000000                4.290219
# ...                         ...                     ...
# 1828                   1.231914                4.290219
# 1829                  20.195669                4.290219
# 1830                   2.572417                4.290219
# 1831                   1.000000                2.942344
# 1832                   2.572417                2.942344
#
#       day_sin__elas____lag7  month_sin__elas____lag7  \
# 0                 24.678504                      4.0
# 1                 24.678504                      4.0
# 2                  6.430184                      4.0
# 3                  3.064220                      4.0
# 4                  1.903585                      4.0
# ...                     ...                      ...
# 1828               6.430184                      4.0
# 1829               3.064220                      4.0
# 1830               1.903585                      4.0
# 1831               1.388509                      4.0
# 1832               1.137166                      4.0
#
#       weekday_sin__elas____lag7  week_sin__elas____lag7  day__elas____lag7  \
# 0                  5.311941e+00                1.303931           1.000000
# 1                  5.311941e+00                1.303931           1.000000
# 2                  1.052095e+00                1.303931           0.250000
# 3                  1.635964e+00                1.303931           0.111111
# 4                  1.667044e+31                1.303931           0.062500
# ...                         ...                     ...                ...
# 1828               5.311941e+00                1.303931           0.250000
# 1829               1.052095e+00                1.303931           0.111111
# 1830               1.635964e+00                1.303931           0.062500
# 1831               1.667044e+31                1.514842           0.040000
# 1832               1.635964e+00                1.514842           0.027778
#
#       month__elas____lag7  ...  LGasSLPana_rel  HGasRLMmT_rel  LGasRLMmT_rel  \
# 0                0.008264  ...        0.042676       0.327516       0.123185
# 1                0.008264  ...        0.041335       0.365071       0.140121
# 2                0.008264  ...        0.037169       0.376579       0.133089
# 3                0.008264  ...        0.046572       0.353174       0.136137
# 4                0.008264  ...        0.040398       0.344013       0.134927
# ...                   ...  ...             ...            ...            ...
# 1828             0.008264  ...        0.011266       0.492441       0.066301
# 1829             0.008264  ...        0.013335       0.471455       0.062271
# 1830             0.008264  ...        0.016028       0.398917       0.054946
# 1831             0.008264  ...        0.017139       0.379095       0.054878
# 1832             0.008264  ...        0.018356       0.439811       0.062180
#
#       HGasRLMoT_rel  LGasRLMoT_rel     gdp    gasprice  gasprice_adj  \
# 0          0.012448       0.011216  843190   18.550000     18.550000
# 1          0.011983       0.011547  843190   18.580000     18.580000
# 2          0.016341       0.011597  843190   18.310000     18.310000
# 3          0.014215       0.009568  843190   18.543333     18.543333
# 4          0.012484       0.008905  843190   18.776667     18.776667
# ...             ...            ...     ...         ...           ...
# 1828       0.026228       0.000896  946230  125.445000     47.031000
# 1829       0.024862       0.000710  946230  114.785000     73.271000
# 1830       0.023780       0.000863  946230  113.085000     57.500000
# 1831       0.022431       0.000841  946230  111.385000     56.474000
# 1832       0.023570       0.000588  946230  109.685000     57.732000
#
#          elprice   co2price
# 0      37.120000   7.510000
# 1      37.120000   7.660000
# 2      37.120000   7.880000
# 3      37.120000   7.893333
# 4      37.120000   7.906667
# ...          ...        ...
# 1828  222.630000  76.130000
# 1829  203.250000  76.210000
# 1830  191.053333  76.590000
# 1831  178.856667  76.970000
# 1832  166.660000  77.350000
#
# [1833 rows x 576 columns]

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=50/1833, shuffle=False)
X_train_s, X_test_s, y_train_s, y_test_s = train_test_split(X, y, test_size=50/1833, shuffle=True)

# %%
from sklearn.linear_model import SGDRegressor
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import Pipeline

# Set it as the mod variable
mod = SGDRegressor(random_state=123)
scaler = StandardScaler()

pipe = Pipeline(
    [
      ('scaler', scaler),
      ('model', mod)
    ])

#Fit and predict the pipe, print results
pred = pipe.fit(X_train,y_train).predict(X_test)
pred_s = pipe.fit(X_train_s,y_train_s).predict(X_test_s)

pred[0:4] |_| print
pred_s[0:4] |_| print
# Out:
# 1956482070.645061
# 2100248606.31048
# 2111899323.3851275
# 2063649651.434754
# 1309250477.0131612
# 1876576920.5598705
# 4337228574.995209
# 1874441217.8065279
# array([None, None, None, None], dtype=object)

# %%
# How does the data look after seeing the description?

plt.scatter(pred, y_test);

# %%
from sklearn import metrics
import numpy as np

print('Mean Absolute Error:', metrics.mean_absolute_error(y_test, pred))
print('Mean Squared Error:', metrics.mean_squared_error(y_test, pred))
print('Root Mean Squared Error:', np.sqrt(metrics.mean_squared_error(y_test, pred)))
print('R squared:', metrics.r2_score(y_test, pred))
# Out:
# Mean Absolute Error: 1358547961.2369368
# Mean Squared Error: 7.546655010898475e+19
# Root Mean Squared Error: 8687148560.315102
# R squared: -1131.110867876306

# %%
# How does the data look after seeing the description?

plt.scatter(pred_s, y_test_s);

# %%
print('Mean Absolute Error:', metrics.mean_absolute_error(y_test_s, pred_s))
print('Mean Squared Error:', metrics.mean_squared_error(y_test_s, pred_s))
print('Root Mean Squared Error:', np.sqrt(metrics.mean_squared_error(y_test_s, pred_s)))
print('R squared:', metrics.r2_score(y_test_s, pred_s))
# Out:
# Mean Absolute Error: 41700750.48476181
# Mean Squared Error: 3029078277429551.5
# Root Mean Squared Error: 55037062.76164773
# R squared: 0.9946638347843483
